# %% [markdown]
# # 00 · Setup
#
# Run this cell **once per Colab session** to:
# 1. Clone / update the repo
# 2. Install dependencies
# 3. Authenticate Google Earth Engine
#
# ---

# %%
# ── 1. Clone repo ──────────────────────────────────────────────
REPO_URL = 'https://github.com/YOUR_USERNAME/geo_sp_project.git'  # ← 改成你的 GitHub URL

import os
if os.path.exists('/content/geo_sp_project'):
    # %cd /content/geo_sp_project
    # !git pull
else:
    # !git clone {REPO_URL} /content/geo_sp_project
    # %cd /content/geo_sp_project

print('✅ Repo ready')

# %%
# ── 2. Install dependencies ────────────────────────────────────
# !pip install -q geopandas shapely requests folium pandas numpy geemap earthengine-api
# !pip install -q osmnx scipy pyarrow
print('✅ Packages installed')

# %%
# ── 3. Add src to path & authenticate EE ──────────────────────
import sys
sys.path.append('/content/geo_sp_project/src')
sys.path.append('/content/geo_sp_project/configs')

import config
from geo_sp.auth import init_ee

init_ee(config.EE_PROJECT)
print('\n🎉 All set! You can now open any notebook in the notebooks/ folder.')
